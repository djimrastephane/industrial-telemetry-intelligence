# %% [markdown]
# # 02 - Baseline Analysis
#
# Step 3 of the Karpathy method: add dumb baselines before anything fancier.
# These are the metrics any later model has to beat to justify its complexity.

# %%
import sys
sys.path.insert(0, "..")

from src.data_cleaning import load_and_clean_all
from src.baseline_models import (
    average_lap_time_by_driver,
    fastest_lap_per_driver,
    consistency_score,
    degradation_summary,
)
from src.visualisation import plot_lap_times, plot_tyre_life_vs_laptime

laps, weather, telemetry = load_and_clean_all()

# %%
average_lap_time_by_driver(laps)
# Out:
#    Driver  AvgLapTimeSeconds
# 0     VER          96.561750
# 1     PER          96.913321
# 2     SAI          96.950571
# 3     LEC          97.252500
# 4     NOR          97.339857
# 5     HAM          97.356143
# 6     RUS          97.362536
# 7     PIA          97.469661
# 8     ALO          97.820536
# 9     STR          97.995429
# 10    ZHO          98.303636
# 11    BOT          98.317963
# 12    RIC          98.327855
# 13    MAG          98.340164
# 14    HUL          98.342164
# 15    TSU          98.377073
# 16    ALB          98.413455
# 17    OCO          98.718818
# 18    GAS          98.725800
# 19    SAR          99.202943

# %%
fastest_lap_per_driver(laps)
# Out:
#    Driver  LapNumber  LapTimeSeconds Compound
# 0     VER       39.0          92.608     SOFT
# 1     LEC       36.0          94.090     HARD
# 2     ALO       48.0          94.199     HARD
# 3     PER       40.0          94.364     SOFT
# 4     NOR       35.0          94.476     HARD
# 5     SAI       44.0          94.507     HARD
# 6     HAM       39.0          94.722     HARD
# 7     SAR       42.0          94.735     SOFT
# 8     PIA       37.0          94.774     HARD
# 9     GAS       45.0          94.805     SOFT
# 10    HUL       46.0          94.834     SOFT
# 11    RUS       40.0          95.065     HARD
# 12    RIC       37.0          95.163     SOFT
# 13    ZHO       30.0          95.458     HARD
# 14    MAG       34.0          95.570     HARD
# 15    STR       30.0          95.632     HARD
# 16    ALB       40.0          95.723     HARD
# 17    TSU       37.0          95.833     HARD
# 18    BOT       33.0          96.202     HARD
# ...

# %%
consistency_score(laps)
# Out:
#    Driver  LapTimeStdSeconds
# 0     BOT           3.408467
# 1     STR           3.926391
# 2     SAI           3.972394
# 3     HAM           4.012924
# 4     LEC           4.038726
# 5     PER           4.040948
# 6     NOR           4.062149
# 7     ZHO           4.064083
# 8     MAG           4.080483
# 9     TSU           4.101737
# 10    ALB           4.122689
# 11    RUS           4.126364
# 12    RIC           4.157450
# 13    OCO           4.165260
# 14    ALO           4.183370
# 15    VER           4.194794
# 16    PIA           4.387157
# 17    GAS           5.483390
# 18    HUL           6.031883
# 19    SAR           6.670565

# %%
degradation_summary(laps)
# Out:
#    Driver  Stint Compound  Laps  DegradationSecondsPerLap  \
# 0     ALB    1.0     SOFT    14                  0.095547
# 1     ALB    2.0     HARD    21                 -0.230949
# 2     ALB    3.0     HARD    20                 -0.249041
# 3     ALO    1.0     SOFT    14                  0.097987
# 4     ALO    2.0     HARD    26                 -0.141500
# ..    ...    ...      ...   ...                       ...
# 57    VER    2.0     HARD    20                 -0.221695
# 58    VER    3.0     SOFT    20                 -0.282119
# 59    ZHO    1.0     SOFT     8                  0.342619
# 60    ZHO    2.0     HARD    19                 -0.248700
# 61    ZHO    3.0     HARD    28                 -0.113930
#
#     StartingLapTimeEstimate
# 0                 98.198681
# 1                101.628062
# 2                 99.969226
# 3                 97.973385
# 4                100.150594
# ..                      ...
# 57                99.204153
# 58                98.735047
# ...

# %%
plot_lap_times(laps[laps["Driver"].isin(["VER", "LEC"])])

# %%
plot_tyre_life_vs_laptime(laps[laps["Driver"].isin(["VER", "LEC"])])

# %% [markdown]
# ## Industrial reading
#
# `DegradationSecondsPerLap` is the same shape as a wear-rate slope on a vibration or temperature trend: a positive slope means the component (tyre / pump / ESP) is degrading over its run, and the slope magnitude is directly comparable across stints, the same way you'd compare wear rates across maintenance intervals.
